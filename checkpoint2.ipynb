# %%
import pandas as pd

# %%
file_path ="/content/Warehouse_and_Retail_Sales.csv"

df = pd.read_csv(file_path)

print(df.head())
# Out:
#    YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0  2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1  2020      1                          PWSWN INC    100024
# 2  2020      1            RELIABLE CHURCHILL LLLP      1001
# 3  2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4  2020      1               DIONYSOS IMPORTS INC    100293
#
#                       ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                  BOOTLEG RED - 750ML      WINE          0.00
# 1            MOMENT DE PLAISIR - 750ML      WINE          0.00
# 2  S SMITH ORGANIC PEAR CIDER - 18.7OZ      BEER          0.00
# 3        SCHLINK HAUS KABINETT - 750ML      WINE          0.00
# 4       SANTORINI GAVALA WHITE - 750ML      WINE          0.82
#
#    RETAIL TRANSFERS  WAREHOUSE SALES
# 0               0.0              2.0
# 1               1.0              4.0
# 2               0.0              1.0
# 3               0.0              1.0
# ...

# %% [markdown]
# # **DATA UNDERSTANDING**
#
# dataset ini diperoleh dari Kaggle-gudang dan penjualan sewaan

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Warehouse_and_Retail_Sales.csv")

# %% [markdown]
# **Cek jumlah baris dan kolom**
#
# dataset ini memiliki 610 baris dan 9 kolom

# %%
print("Jumalah baris dan kolom:", df.shape)
# Out:
# Jumalah baris dan kolom: (307645, 9)

# %% [markdown]
# **2. cek tipe data setiap kolom**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307645 entries, 0 to 307644
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   YEAR              307645 non-null  int64
#  1   MONTH             307645 non-null  int64
#  2   SUPPLIER          307478 non-null  object
#  3   ITEM CODE         307645 non-null  object
#  4   ITEM DESCRIPTION  307645 non-null  object
#  5   ITEM TYPE         307644 non-null  object
#  6   RETAIL SALES      307642 non-null  float64
#  7   RETAIL TRANSFERS  307645 non-null  float64
#  8   WAREHOUSE SALES   307645 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 21.1+ MB

# %% [markdown]
# **3. Tampilkan 5 data pertama dan terakhir untuk melihat isi dataset (jika baris banyak)**

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# ...

# %% [markdown]
# **4. Statistik deskriptif**

# %%
df.describe()
# Out:
#                 YEAR          MONTH   RETAIL SALES  RETAIL TRANSFERS  \
# count  307645.000000  307645.000000  307642.000000     307645.000000
# mean     2018.438525       6.423862       7.024071          6.936465
# std         1.083061       3.461812      30.986238         30.237195
# min      2017.000000       1.000000      -6.490000        -38.490000
# 25%      2017.000000       3.000000       0.000000          0.000000
# 50%      2019.000000       7.000000       0.320000          0.000000
# 75%      2019.000000       9.000000       3.267500          3.000000
# max      2020.000000      12.000000    2739.000000       1990.830000
#
#        WAREHOUSE SALES
# count    307645.000000
# mean         25.294597
# std         249.916798
# min       -7800.000000
# 25%           0.000000
# 50%           1.000000
# 75%           5.000000
# max       18317.000000

# %% [markdown]
# # **DATA PREPARATION**
#
# dataset ini diperoleh dari Kaggle-gudang dan penjualan sewaan

# %% [markdown]
# # **A. Pengecekan terhadap data**
#
# **1.Nilai yang hilang (missing values)**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# YEAR                0.000000
# MONTH               0.000000
# SUPPLIER            0.054283
# ITEM CODE           0.000000
# ITEM DESCRIPTION    0.000000
# ITEM TYPE           0.000325
# RETAIL SALES        0.000975
# RETAIL TRANSFERS    0.000000
# WAREHOUSE SALES     0.000000
# dtype: float64

# %% [markdown]
# **2.Duplicated value (nilai duplicate)**

# %%
duplicate_rows = df[df.duplicated()]
print("\nJumlah Baris Duplikat:", len(duplicate_rows))
# Out:
# Jumlah Baris Duplikat: 0

# %% [markdown]
# **3.outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# YEAR                         0.000000
# MONTH                        0.000000
# RETAIL SALES                15.606950
# RETAIL TRANSFERS            16.643859
# WAREHOUSE SALES             14.352907

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# ...

# %% [markdown]
# **4.Inconsistent Value**
#
# menurut saya dataset yang saya teliti tidak memiliki nilai yang tidak konsisten

# %% [markdown]
# # **B.Penanganan terhadap data**
#
# **1. Nilai yang hilang**

# %%
missing_values = df.isnull().sum()

# %% [markdown]
# tidak ada data yang hilang

# %% [markdown]
# **2.Duplicated Values**

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# ...

# %% [markdown]
# **3.Outliers**

# %%
def impute_outliers(col):
    median = col.median()
    return col.apply(lambda x: median if x < lower_bound[col.name] or x > upper_bound[col.name] else x)

# %% [markdown]
# kita cek ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# YEAR                         0.000000
# MONTH                        0.000000
# RETAIL SALES                15.606950
# RETAIL TRANSFERS            16.643859
# WAREHOUSE SALES             14.352907

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# ...

# %% [markdown]
# **4.Inconsisten value**
#
# dari dataset yang saya teliti tidak ditemukan nilai yang tidak konsisten

# %% [markdown]
# #**Kontruksi data.. (penambahan kolom)**
#
# **menambahkan kolom label iteml**

# %%
def categorize_risk(value):
    if value < 10:
        return "Low"
    elif value < 20:
        return "Moderate"
    else:
        return "High"

df["ITEM LABEL"] = df['WAREHOUSE SALES'].apply(categorize_risk)

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# ...

# %% [markdown]
# **Menambahkan kolom penjualan sukses**

# %%
df["SUCCESSFUL SALES"] = ((df['RETAIL SALES'] + df['RETAIL TRANSFERS']) / df['WAREHOUSE SALES']) * 100

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# ...

# %% [markdown]
# # **Reduksi data**
#
# Mengapa kolom dihapus untuk memperkecil ukuran file yang *perlu didownload* dan fokus pada infomasi utama

# %%
columns_to_drop = ['ITEM CODE', 'ITEM DESCRIPTION', 'ITEM TYPE']
df_cleaned = df.drop(columns=columns_to_drop)

# %%
df
# Out:
#         YEAR  MONTH                           SUPPLIER ITEM CODE  \
# 0       2020      1  REPUBLIC NATIONAL DISTRIBUTING CO    100009
# 1       2020      1                          PWSWN INC    100024
# 2       2020      1            RELIABLE CHURCHILL LLLP      1001
# 3       2020      1          LANTERNA DISTRIBUTORS INC    100145
# 4       2020      1               DIONYSOS IMPORTS INC    100293
# ...      ...    ...                                ...       ...
# 307640  2020      9                           DOPS INC     97896
# 307641  2020      9                 ANHEUSER BUSCH INC     97918
# 307642  2020      9                       HEINEKEN USA     97942
# 307643  2020      9            RELIABLE CHURCHILL LLLP     97950
# 307644  2020      9            RELIABLE CHURCHILL LLLP     97969
#
#                                    ITEM DESCRIPTION ITEM TYPE  RETAIL SALES  \
# 0                               BOOTLEG RED - 750ML      WINE          0.00
# ...
